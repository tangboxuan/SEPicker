# %%
import pandas as pd
import numpy as np

# %%
mappings = pd.read_csv('../static/Module-Mappings.csv')
areas = pd.read_csv('../static/Country-Continent-Language.csv')

# %%
regions = []
countries = []
for uni in mappings['Partner University']:
    regions.append(areas[areas['University'] == uni]['Continent'].iloc[0])
    countries.append(areas[areas['University'] == uni]['Country'].iloc[0])

# %%
mappings['Country'] = countries
mappings['Continent'] = regions

# %%
mappings.to_csv('../static/Module-Mappings.csv',index=False)

# %%
def get_department(mod_code):
    output = ''
    numbers = '1234567890'
    for char in mod_code:
        if char not in numbers:
            output += char
        else:
            break
    return output

def get_level(mod_code):
    for char in mod_code:
        if char in '1234567890':
            return char

# %%
mod_codes1 = []
mod_codes2 = []
level = []
for mod in zip(mappings['NUS Module 1'],mappings['NUS Module 2']):
    try:
        mod_codes1.append(get_department(mod[0]))
    except:
        mod_codes1.append(np.nan)
        
    try:
        mod_codes2.append(get_department(mod[1]))
    except:
        mod_codes2.append(np.nan)
        
    try:
        level.append(get_level(mod[0]))
    except:
        level.append(np.nan)

# %%
mappings.to_csv('../static/Module-Mappings.csv',index=False)

# %%
mappings
# Out:
#                               Faculty   Partner University PU Module 1  \
# 0                 School of Computing     Aalto University   CS--E4320
# 1              Faculty of Engineering     Aalto University    25C00200
# 2              Faculty of Engineering     Aalto University  KIE98.7011
# 3                 School of Computing     Aalto University       C3130
# 4                 School of Computing     Aalto University    CS-C3130
# ...                               ...                  ...         ...
# 13026             NUS Business School  Zhejiang University    20120490
# 13027             NUS Business School  Zhejiang University    20120661
# 13028             NUS Business School  Zhejiang University    20190130
# 13029             NUS Business School  Zhejiang University      192340
# 13030  School of Design & Environment  Zhejiang University    12120120
#
#                                    PU Module 1 Title  PU Mod1 Credits  \
# 0                     Cryptography and Data Security              5.0
# 1         Entrepreneurship and Innovation Management              3.0
# 2                                         Finnish 1A              2.0
# 3                               Information Security              5.0
# 4                               Information Security              5.0
# ...                                              ...              ...
# 13026               STRATEGIC MANAGEMENT IN BUSINESS              3.0
# 13027                        SUPPLY CHAIN MANAGEMENT              2.0
# 13028                        SUPPLY CHAIN MANAGEMENT              2.0
# 13029  THEORY AND IMPLEMENTATION OF INVESTMENT BANKS              3.0
# 13030                      Urban Planning and Design              5.0
#
#       PU Module 2 PU Module 2 Title  PU Mod2 Credits NUS Module 1  \
# 0             NaN               NaN              NaN       CS2107
# 1             NaN               NaN              NaN       MT4001
# 2             NaN               NaN              NaN       EX1030
# 3             NaN               NaN              NaN       CS2107
# 4             NaN               NaN              NaN       CS2107
# ...           ...               ...              ...          ...
# 13026         NaN               NaN              NaN      BSP3701
# 13027         NaN               NaN              NaN      DOS3701
# 13028         NaN               NaN              NaN      DOS3701
# 13029         NaN               NaN              NaN     FIN3761Y
# 13030         NaN               NaN              NaN       AR4101
#
#                    NUS Module 1 Title  NUS Mod1 Credits NUS Module 2  \
# 0      Introduction to Information Se               4.0          NaN
# 1      Innovation and Entrepreneurial               4.0          NaN
# 2                        Exchange UEM               1.0          NaN
# 3      Introduction to Information Se               4.0          NaN
# 4      Introduction to Information Se               4.0          NaN
# ...                               ...               ...          ...
# 13026            Strategic Management               4.0          NaN
# 13027         Supply Chain Management               4.0          NaN
# 13028         Supply Chain Management               4.0          NaN
# 13029               Topics in Finance               4.0          NaN
# 13030                        Design 7               8.0          NaN
#
#       NUS Module 2 Title  NUS Mod2 Credits Pre Approved?  Country Continent
# 0                    NaN               NaN             N  Finland    Europe
# 1                    NaN               NaN             Y  Finland    Europe
# 2                    NaN               NaN             N  Finland    Europe
# 3                    NaN               NaN           NaN  Finland    Europe
# 4                    NaN               NaN             N  Finland    Europe
# ...                  ...               ...           ...      ...       ...
# 13026                NaN               NaN             Y    China      Asia
# 13027                NaN               NaN             Y    China      Asia
# 13028                NaN               NaN             Y    China      Asia
# 13029                NaN               NaN             Y    China      Asia
# 13030                NaN               NaN             N    China      Asia
#
# [13031 rows x 17 columns]
